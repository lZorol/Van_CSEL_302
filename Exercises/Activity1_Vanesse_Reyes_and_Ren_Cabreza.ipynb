# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('Email_Exchanges.csv')
data2 = pd.read_csv('Security_Camera_Logs.csv')
data3 = pd.read_csv('Visitor_Logs.csv')
data4 = pd.read_csv('Inventory_Records.csv')

data1.head()
data2.head()
data3.head()
data4.head()
# Out:
#   Item ID           Description    Last Known Location Movement Date  \
# 0   SP001      Sapphire Phoenix  Ancient World Exhibit    2024-05-09
# 1   SP002  Golden Falcon Statue         Treasure Trove    2024-05-07
# 2   SP003       Emerald Serpent          Reptile Realm    2024-05-08
# 3   SP004         Platinum Lion      Kingdom of Beasts    2024-05-10
# 4   SP005       Diamond Unicorn     Mythical Creatures    2024-05-06
#
#   Authorized Personnel
# 0             John Doe
# 1           Jane Smith
# 2          Emily White
# 3        Michael Brown
# 4         Olivia Green
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_18.groupby('Item ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# Story
#
# On 2024-5-10 it was emailed that there are security concern, but on 2024-5-8 there was no activity or visitors on the 5-8, but in 5-10 there is a suspicious activity on email as showed, there is also a visitors on that exact time 10 am and base on email and secuirty cameras there is a huge load of visitors entering the exhibit, if the sapphire phoenix is stole it is usally the date of 5-10 because there is a several visitors on the area and base on email there is a suspcious act on noticed base on email, and there is a shadow spotted on 10am.
#
# i suspect that the suspect i among the visitors, and not the autorized personel but i conclude that michael brown possibly one of the suspect. now lets bring down the main suspect base on evidences.
#
#
# Email exchanges
#
# 2024-05-08 - security concern was reported base on email
#
# 2024 -05-09 - there is a reminder about protocols but, there is a possibility that the suspecft tampered with the security camera
#
# 2024 - 05 - 10 - suspicious activity is seen
# security camera there is a detected movement and shadowy figure spotted (i think this is the date where the crime or happened)
#
# so lets bring down the autorized personel and visitors
#
# John Doe - Maybe, he is the handler but there is lack of lack of evidence and this is the time where the security protocols exposed
#
# Tresure trove-
#
# to be direct - I suspect that the suspect is one of the visitors because on how the flow and the security camera acted but i also think that one of the autorized personel is involved.
